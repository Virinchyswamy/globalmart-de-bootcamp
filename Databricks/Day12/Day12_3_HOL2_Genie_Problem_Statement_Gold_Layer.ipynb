# %% [markdown]
# # Day 12 | HOL 2: The Genie Problem Statement**GlobalMart Data Engineering Bootcamp**| | ||---|---|| **Calendar slot** | Day 12 · HOL 2 (deferred from ILT 1) || **Builds on** | Day 12 ILT 1 (semantic-layer concepts, rehearsed on a practice copy), Day 7 HOL 2 (`gbmart.gold.fact_sales`, its 6 dimensions, `vw_monthly_category_sales`, `vw_regional_sales`), Day 12 HOL 1 (Unity Catalog permissions/masking — one of this session's own questions deliberately touches that) || **Companion page** | `Day12_3_HOL2_Genie_Problem_Statement_Gold_Layer.html` — Phases 1-3 (creating the real Genie Agent, asking it questions) live there, not here, since a Genie Agent is built entirely by clicking through the Databricks workspace UI and chatting with it, not by running notebook code || **Reads (real, read-only)** | `gbmart.gold.fact_sales`, its 6 dimensions, and its 2 certified views — row-count/existence checks only || **Writes** | None. This notebook creates nothing and alters nothing — it only confirms the real objects Phase 1's Genie Agent will point at are actually there |### Learning Objectives- Confirm, before touching the UI, that the 8 real Gold-layer objects a Genie Agent needs (the fact table, 6 dimensions, 2 certified views) are actually present and queryable- Build a real Genie Agent over `gbmart.gold` and register known-good sample questions against it- Deliberately push a working Genie Agent past its comfort zone — an ambiguous question, a real join across two views, a governed column, a question with no answer in scope — and record what actually happens- Recognize, honestly, which parts of a Genie workflow are scriptable (verifying the data underneath) and which are not (building the Agent itself, chatting with it)---**Instructor note, same honesty as ILT 1:** there is no cell anywhere in this notebook that creates a Genie Agent or calls a Genie API — that step is UI-only, by Databricks' own design, and faking it with code that wouldn't actually work would teach the wrong lesson. What this notebook *does* do — verify the real data Phase 1 depends on, and give you a structured place to log your Phase 2/3 findings — is honestly scriptable, so it's scripted.**Safety note:** every statement in this notebook is a read (`SELECT`/`COUNT`) against the real `gbmart.gold` layer. Nothing here writes, alters, or drops anything, and nothing starts a job, workflow, pipeline, SQL warehouse, or cluster.**Instructions:** Run Phase A first. Then switch to the companion HTML page for the "Read First" docs questions and Phases 1-3. Come back here afterward to fill in your Reflection Log before submitting.

# %% [markdown]
# ## Why This, NowILT 1 taught the concepts — what a Genie Agent is, what a semantic layer is, why comments and certified views matter — and rehearsed the scriptable parts (`COMMENT`, `ALTER TABLE ... COMMENT`) on a throwaway practice copy, on purpose. It was explicit that actually creating a Genie Agent is UI-only and would be a separate, later session. This is that session: GlobalMart's VP of Sales currently files a ticket every time she wants one number out of Gold, waits a day, and gets back a screenshot she can't drill into. Today you give her — and anyone like her — a real, working way to ask `gbmart.gold` questions in plain English, live, with no data engineer in the loop.

# %% [markdown]
# ---## Phase A — Verify the 8 Real Objects Genie Will Point AtThe companion page's Phase 1 has you create a Genie Agent scoped to exactly 8 objects: `fact_sales`, its 6 dimensions, and its 2 certified views. Before clicking through that UI, confirm all 8 actually exist and are queryable right now — the same "don't build on top of something you haven't verified" habit as Day 7 HOL 1's dimension health check.

# %%
tables_to_check = [    "fact_sales",    "dim_customer", "dim_product", "dim_date",    "dim_address", "dim_payment_method", "dim_orders",    "vw_monthly_category_sales", "vw_regional_sales",]print(f"{'Object':<28} {'Rows':>10}")print("-" * 40)for obj in tables_to_check:    df = spark.table(f"gbmart.gold.{obj}")    print(f"{obj:<28} {df.count():>10,}")

# %% [markdown]
# If any of the 8 above is missing or shows 0 rows, go back and re-run the relevant Day 7 HOL 2 (fact_sales, both views) or Day 6 HOL 1 (dimensions) cell before continuing — Phase 1's Genie Agent is only as good as the real data sitting underneath it.

# %% [markdown]
# ## → Now Go Do the Companion PageSwitch to `Day12_3_HOL2_Genie_Problem_Statement_Gold_Layer.html`:1. **Read First** — the 4 real-docs questions, not skippable.2. **Phase 1** — build the Genie Agent over the 8 objects you just verified above.3. **Phase 2** — register and confirm the 4 known-good sample questions.4. **Phase 3** — ask at least 5 questions of your own, designed to find where Genie struggles.**Come back here once Phase 3 is done, to fill in your Reflection Log.**

# %% [markdown]
# ---## Reflection Log — Fill This In After Phases 2 and 3### Phase 2 — Known-Good QuestionsRecord, for each of the 4 provided questions, whether Genie's answer matched what the underlying view's SQL would actually return.| # | Question | Genie's answer matched the view's SQL? | Notes ||---|---|---|---|| 1 | "What was our revenue by category last month?" | _______ | _______ || 2 | "Which states generate the most revenue?" | _______ | _______ || 3 | "What is our average discount by category?" | _______ | _______ || 4 | "How many orders came from each region?" | _______ | _______ |### Phase 3 — Your Own 5+ QuestionsFor each question you asked, log what you asked, what Genie actually did, and your verdict (correct / wrong / honestly uncertain — e.g. it asked you to clarify, or said it didn't have the data). Patterns across your 5 matter more than any single result.| # | Question asked | What Genie did | Verdict ||---|---|---|---|| 1 | _______ | _______ | _______ || 2 | _______ | _______ | _______ || 3 | _______ | _______ | _______ || 4 | _______ | _______ | _______ || 5 | _______ | _______ | _______ |**At least one of your 5 should be a genuine "Genie got this wrong, refused, or asked for clarification" moment** — if all 5 landed perfectly on the first try, the companion page's own guidance is that your questions weren't hard enough yet.

# %% [markdown]
# ## Key Takeaways1. **The data underneath a Genie Agent is worth verifying before you build the Agent** — Phase A above is the scriptable half of "make sure Genie has something real to point at."2. **Building the Genie Agent itself, and chatting with it, is UI-only** — no notebook cell creates one, by design, the same honesty ILT 1 established.3. **Known-good questions (Phase 2) prove Genie *can* work; they don't prove you understand it** — that's what Phase 3's self-written questions are actually for.4. **A working Genie Agent has real limits** — ambiguous phrasing, questions that need a real join across more than one certified view, and questions with no answer in scope are all places it can guess wrong instead of asking for clarification or admitting it doesn't know.5. **Governance you set up earlier (Day 11 ILT 4, Day 12 HOL 1) applies to Genie automatically** — a masked column stays masked whether the query came from you typing SQL or from Genie generating it on your behalf.### Submission Checklist- [ ] Phase A verification shows all 8 real Gold objects present and queryable- [ ] Read both real Genie docs pages and answered all 4 Read First questions on the companion page- [ ] Genie Agent created over `fact_sales`, its 6 dimensions, and both certified views, with Instructions written in your own words- [ ] All 4 known-good sample questions registered and confirmed correct in the live Genie chat- [ ] 5+ self-written questions asked, at least one exposing a real limitation- [ ] Reflection Log above filled in for all 4 known-good questions and all 5+ self-written questions
